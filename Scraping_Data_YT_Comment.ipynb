# %% [markdown]
# <a href="https://colab.research.google.com/github/ankirani/My-Portofolio-Data-Science/blob/main/Scraping_Data_YT_Comment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-api-python-client

# %%
import googleapiclient.discovery
import pandas as pd

api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyDTiM6o3yFy-NBtoUJFJi0f2OCY-6_BWWw"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY
)

request = youtube.commentThreads().list(
    part="snippet",
    videoId="dY_3acmFFRQ",
    maxResults=100
)
response = request.execute()

comments = []

for item in response['items']:
  comment = item['snippet']['topLevelComment']['snippet']
  comments.append([
      comment['authorDisplayName'],
      comment['publishedAt'],
      comment['updatedAt'],
      comment['likeCount'],
      comment['textDisplay']
  ])

df = pd.DataFrame(comments, columns=['author', 'published_at', 'updated_at','like_count', 'text'])

df.head(10)
# Out:
#                author          published_at            updated_at  like_count  \
# 0          @Ruangguru  2024-07-03T06:39:10Z  2024-07-03T06:39:10Z        2106
# 1   @IsmailiaHomeTeam  2025-05-17T01:36:15Z  2025-05-17T01:36:15Z           0
# 2          @cs1tim138  2025-05-15T13:52:12Z  2025-05-15T13:52:12Z           0
# 3      @MILKY_TEA-e2d  2025-05-15T10:53:55Z  2025-05-15T10:53:55Z           0
# 4  @mitraofficial3841  2025-05-14T14:54:57Z  2025-05-14T14:54:57Z           1
# 5  @mitraofficial3841  2025-05-14T14:54:10Z  2025-05-14T14:54:10Z           1
# 6       @Nathania4120  2025-05-11T09:59:10Z  2025-05-11T09:59:10Z           0
# 7  @rismakadisono6407  2025-05-01T22:33:01Z  2025-05-01T22:33:01Z           0
# 8           @Molz2005  2025-04-29T19:17:57Z  2025-04-29T19:17:57Z           1
# 9      @ariefasih1209  2025-04-27T09:07:58Z  2025-04-27T09:07:58Z           3
#
#                                                 text
# 0  Yuk, konsultasi dan klaim diskonnya sekarang d...
# ...

# %%
#export ke CSV
df.to_csv('coc_ep1_comments.csv', index=False)

# %%
#export ke excel
df.to_excel('coc_ep1_comments.xlsx', index=False)
